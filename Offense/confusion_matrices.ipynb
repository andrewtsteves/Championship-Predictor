# %%
import Model_testing as M
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

# %%
cm_lr = M.matrix_lr

disp_lr = ConfusionMatrixDisplay(confusion_matrix = cm_lr, display_labels = ['Loss', 'Win'])
disp_lr.plot(cmap = 'Blues')

plt.grid(False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Logistic Regression')
plt.show()

# %%
cm_dt = M.matrix_DT

disp_lr = ConfusionMatrixDisplay(confusion_matrix = cm_dt, display_labels = ['Loss', 'Win'])
disp_lr.plot(cmap = 'Blues')

plt.grid(False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Decision Tree')
plt.show()

# %%
cm_svc = M.matrix_svc

disp_lr = ConfusionMatrixDisplay(confusion_matrix = cm_svc, display_labels = ['Loss', 'Win'])
disp_lr.plot(cmap = 'Blues')

plt.grid(False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Support Vector Machine')
plt.show()

# %%
cm_rf = M.matrix_RF

disp_lr = ConfusionMatrixDisplay(confusion_matrix = cm_rf, display_labels = ['Loss', 'Win'])
disp_lr.plot(cmap = 'Blues')

plt.grid(False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Random Forest')
plt.show()

# %%
cm_MLP = M.matrix_MLP

disp_lr = ConfusionMatrixDisplay(confusion_matrix = cm_MLP, display_labels = ['Loss', 'Win'])
disp_lr.plot(cmap = 'Blues')

plt.grid(False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Multilayer Perceptron')
plt.show()
